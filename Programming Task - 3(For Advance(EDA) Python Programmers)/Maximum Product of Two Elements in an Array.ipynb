# %%
nums = [[3, 4, 5, 2], [1, 5, 4, 5], [3, 7]]
for num in nums:
    i = 0
    j = 0
    for k in num:
        if k > i:
            j = i
            i = k
        elif k > j:
            j = k
    print((i - 1) * (j - 1))
# Out:
# 12
# 16
# 12
