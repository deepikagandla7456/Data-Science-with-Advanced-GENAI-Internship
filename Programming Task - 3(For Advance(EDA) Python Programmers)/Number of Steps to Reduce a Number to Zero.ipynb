# %%
nums = [14, 8, 123]
for num in nums:
    steps = 0
    while num > 0:
        if num % 2 == 0:
            num = num // 2
        else:
            num = num - 1
        steps += 1
    print(steps)
# Out:
# 6
# 4
# 12
